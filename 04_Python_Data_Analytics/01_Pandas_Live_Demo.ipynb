# %% [markdown]
# # Pandas
# ## Series

# %%
import numpy as np
import pandas as pd

# %%
lst = [i**2 for i in range(10)]

# %%
pd.Series(lst)
# Out:
# 0     0
# 1     1
# 2     4
# 3     9
# 4    16
# 5    25
# 6    36
# 7    49
# 8    64
# 9    81
# dtype: int64

# %%
number_names = ["zero", "one", "two", "three", "four", "five", "six", "seven", "eight", "nine"]

# %%
pd.Series(lst, number_names)
# Out:
# zero      0
# one       1
# two       4
# three     9
# four     16
# five     25
# six      36
# seven    49
# eight    64
# nine     81
# dtype: int64

# %%
np_arr = np.arange(0,10,2)

# %%
pd.Series(np_arr)
# Out:
# 0    0
# 1    2
# 2    4
# 3    6
# 4    8
# dtype: int64

# %%
dictionary = {"a":1, "b":2, "c":3}

# %%
pd.Series(dictionary)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %% [markdown]
# ## Calculation with series

# %%
import numpy as np
import pandas as pd

# %%
dict1 = {"apples":3, "pears":2, "bananas": 1}
dict2 = {"apples":5, "bananas":2, "grapes":10}

# %%
fruit_series = pd.Series(dict1)
fruit_series2 = pd.Series(dict2)

# %%
fruit_series
# Out:
# apples     3
# pears      2
# bananas    1
# dtype: int64

# %%
fruit_series2
# Out:
# apples      5
# bananas     2
# grapes     10
# dtype: int64

# %%
fruit_series + fruit_series2
# Out:
# apples     8.0
# bananas    3.0
# grapes     NaN
# pears      NaN
# dtype: float64

# %% [markdown]
# ## DataFrames

# %% [markdown]
# ### Create random DataFrame

# %%
cols = ["Cars", "Horses", "Bicycles", "Flowers", "Electricity"]
rows = ["Germany", "USA", "France", "Italy", "China"]

# %%
data = np.random.randint(1,10000,(5,5))
data
# Out:
# array([[ 317, 5429, 9273, 8163, 3043],
#        [3866,   28, 6019, 9709, 9020],
#        [6788, 3498, 1498, 2156, 1883],
#        [ 779, 5888, 7990, 7024, 5540],
#        [ 710, 7861, 7929, 7099, 6309]])

# %%
countries_df = pd.DataFrame(data, index = rows, columns = cols)

# %%
countries_df
# Out:
#          Cars  Horses  Bicycles  Flowers  Electricity
# Germany   317    5429      9273     8163         3043
# USA      3866      28      6019     9709         9020
# France   6788    3498      1498     2156         1883
# Italy     779    5888      7990     7024         5540
# China     710    7861      7929     7099         6309

# %% [markdown]
# ### Accessing values

# %%
countries_df["Cars"]
# Out:
# Germany     317
# USA        3866
# France     6788
# Italy       779
# China       710
# Name: Cars, dtype: int64

# %%
countries_df[["Cars", "Bicycles"]]
# Out:
#          Cars  Bicycles
# Germany   317      9273
# USA      3866      6019
# France   6788      1498
# Italy     779      7990
# China     710      7929

# %%
countries_df[["Cars"]]
# Out:
#          Cars
# Germany   317
# USA      3866
# France   6788
# Italy     779
# China     710

# %%
countries_df.loc["USA"]
# Out:
# Cars           3866
# Horses           28
# Bicycles       6019
# Flowers        9709
# Electricity    9020
# Name: USA, dtype: int64

# %%
countries_df.loc[["USA"]]
# Out:
#      Cars  Horses  Bicycles  Flowers  Electricity
# USA  3866      28      6019     9709         9020

# %%
countries_df.loc[["Germany", "France", "Italy"]]
# Out:
#          Cars  Horses  Bicycles  Flowers  Electricity
# Germany   317    5429      9273     8163         3043
# France   6788    3498      1498     2156         1883
# Italy     779    5888      7990     7024         5540

# %%
countries_df
# Out:
#          Cars  Horses  Bicycles  Flowers  Electricity
# Germany   317    5429      9273     8163         3043
# USA      3866      28      6019     9709         9020
# France   6788    3498      1498     2156         1883
# Italy     779    5888      7990     7024         5540
# China     710    7861      7929     7099         6309

# %% [markdown]
# ### Creating new columns

# %%
countries_df["Transportation"] = countries_df["Cars"] + countries_df["Bicycles"]

# %%
countries_df
# Out:
#          Cars  Horses  Bicycles  Flowers  Electricity  Transportation
# Germany   317    5429      9273     8163         3043            9590
# USA      3866      28      6019     9709         9020            9885
# France   6788    3498      1498     2156         1883            8286
# Italy     779    5888      7990     7024         5540            8769
# China     710    7861      7929     7099         6309            8639

# %% [markdown]
# ### Deleting data

# %%
countries_df["Random_Merit"] = countries_df["Cars"] * countries_df["Bicycles"]

# %%
countries_df
# Out:
#          Cars  Horses  Bicycles  Flowers  Electricity  Transportation  \
# Germany   317    5429      9273     8163         3043            9590
# USA      3866      28      6019     9709         9020            9885
# France   6788    3498      1498     2156         1883            8286
# Italy     779    5888      7990     7024         5540            8769
# China     710    7861      7929     7099         6309            8639
#
#          Random_Merit
# Germany       2939541
# USA          23269454
# France       10168424
# Italy         6224210
# China         5629590

# %%
countries_df.drop("Random_Merit", axis=1, inplace=True)

# %%
countries_df
# Out:
#          Cars  Horses  Bicycles  Flowers  Electricity  Transportation
# Germany   317    5429      9273     8163         3043            9590
# USA      3866      28      6019     9709         9020            9885
# France   6788    3498      1498     2156         1883            8286
# Italy     779    5888      7990     7024         5540            8769
# China     710    7861      7929     7099         6309            8639

# %% [markdown]
# ### Advanced (conditional) selecting

# %%
countries_df[countries_df["Electricity"]>4000]
# Out:
#        Cars  Horses  Bicycles  Flowers  Electricity  Transportation
# USA    3866      28      6019     9709         9020            9885
# Italy   779    5888      7990     7024         5540            8769
# China   710    7861      7929     7099         6309            8639

# %%
countries_df[(countries_df["Flowers"]<9000) & (countries_df["Electricity"]>4000)]
# Out:
#        Cars  Horses  Bicycles  Flowers  Electricity  Transportation
# Italy   779    5888      7990     7024         5540            8769
# China   710    7861      7929     7099         6309            8639

# %% [markdown]
# ### Working with the index

# %%
countries_df.reset_index(inplace=True)
countries_df
# Out:
#      index  Cars  Horses  Bicycles  Flowers  Electricity  Transportation
# 0  Germany   317    5429      9273     8163         3043            9590
# 1      USA  3866      28      6019     9709         9020            9885
# 2   France  6788    3498      1498     2156         1883            8286
# 3    Italy   779    5888      7990     7024         5540            8769
# 4    China   710    7861      7929     7099         6309            8639

# %%
countries_df.rename({"index":"Countries"}, axis=1, inplace=True)
countries_df
# Out:
#   Countries  Cars  Horses  Bicycles  Flowers  Electricity  Transportation
# 0   Germany   317    5429      9273     8163         3043            9590
# 1       USA  3866      28      6019     9709         9020            9885
# 2    France  6788    3498      1498     2156         1883            8286
# 3     Italy   779    5888      7990     7024         5540            8769
# 4     China   710    7861      7929     7099         6309            8639

# %% [markdown]
# ### Multiple DataFrames

# %%
cols = ["Bananas", "Apples"]
rows = ["Germany", "USA", "Ghana", "New Zealand"]
data = np.random.randint(1,1000000,(4,2))

# %%
countries_df2 = pd.DataFrame(data, columns=cols, index=rows).reset_index().rename({"index":"Countries"}, axis=1)
countries_df2
# Out:
#      Countries  Bananas  Apples
# 0      Germany   792738  233463
# 1          USA   855342  267340
# 2        Ghana   270960  532424
# 3  New Zealand   701745  611670

# %% [markdown]
# #### Merging

# %%
pd.merge(countries_df, countries_df2, on="Countries", how="inner")
# Out:
#   Countries  Cars  Horses  Bicycles  Flowers  Electricity  Transportation  \
# 0   Germany   317    5429      9273     8163         3043            9590
# 1       USA  3866      28      6019     9709         9020            9885
#
#    Bananas  Apples
# 0   129295   23939
# 1   967969  907253

# %%
outer_merge_df = pd.merge(countries_df, countries_df2, on="Countries", how="outer")
outer_merge_df
# Out:
#      Countries    Cars  Horses  Bicycles  Flowers  Electricity  \
# 0      Germany   317.0  5429.0    9273.0   8163.0       3043.0
# 1          USA  3866.0    28.0    6019.0   9709.0       9020.0
# 2       France  6788.0  3498.0    1498.0   2156.0       1883.0
# 3        Italy   779.0  5888.0    7990.0   7024.0       5540.0
# 4        China   710.0  7861.0    7929.0   7099.0       6309.0
# 5        Ghana     NaN     NaN       NaN      NaN          NaN
# 6  New Zealand     NaN     NaN       NaN      NaN          NaN
#
#    Transportation   Bananas    Apples
# 0          9590.0  792738.0  233463.0
# 1          9885.0  855342.0  267340.0
# 2          8286.0       NaN       NaN
# 3          8769.0       NaN       NaN
# 4          8639.0       NaN       NaN
# 5             NaN  270960.0  532424.0
# 6             NaN  701745.0  611670.0

# %% [markdown]
# #### Missing Data

# %%
countries_df_large = outer_merge_df.fillna(outer_merge_df.mean())
countries_df_large
# Out:
#      Countries    Cars  Horses  Bicycles  Flowers  Electricity  \
# 0      Germany   317.0  5429.0    9273.0   8163.0       3043.0
# 1          USA  3866.0    28.0    6019.0   9709.0       9020.0
# 2       France  6788.0  3498.0    1498.0   2156.0       1883.0
# 3        Italy   779.0  5888.0    7990.0   7024.0       5540.0
# 4        China   710.0  7861.0    7929.0   7099.0       6309.0
# 5        Ghana  2492.0  4540.8    6541.8   6830.2       5159.0
# 6  New Zealand  2492.0  4540.8    6541.8   6830.2       5159.0
#
#    Transportation    Bananas     Apples
# 0          9590.0  792738.00  233463.00
# 1          9885.0  855342.00  267340.00
# 2          8286.0  655196.25  411224.25
# 3          8769.0  655196.25  411224.25
# 4          8639.0  655196.25  411224.25
# 5          9033.8  270960.00  532424.00
# 6          9033.8  701745.00  611670.00

# %%
outer_merge_df.fillna(value={"Bananas":600000, "Apples":400000}).dropna()
# Out:
#   Countries    Cars  Horses  Bicycles  Flowers  Electricity  Transportation  \
# 0   Germany   317.0  5429.0    9273.0   8163.0       3043.0          9590.0
# 1       USA  3866.0    28.0    6019.0   9709.0       9020.0          9885.0
# 2    France  6788.0  3498.0    1498.0   2156.0       1883.0          8286.0
# 3     Italy   779.0  5888.0    7990.0   7024.0       5540.0          8769.0
# 4     China   710.0  7861.0    7929.0   7099.0       6309.0          8639.0
#
#     Bananas    Apples
# 0  792738.0  233463.0
# 1  855342.0  267340.0
# 2  600000.0  400000.0
# 3  600000.0  400000.0
# 4  600000.0  400000.0

# %% [markdown]
# #### ... and merge again

# %%
pd.merge(countries_df, countries_df2, on="Countries", how="left")
# Out:
#   Countries  Cars  Horses  Bicycles  Flowers  Electricity  Transportation  \
# 0   Germany   317    5429      9273     8163         3043            9590
# 1       USA  3866      28      6019     9709         9020            9885
# 2    France  6788    3498      1498     2156         1883            8286
# 3     Italy   779    5888      7990     7024         5540            8769
# 4     China   710    7861      7929     7099         6309            8639
#
#     Bananas    Apples
# 0  129295.0   23939.0
# 1  967969.0  907253.0
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN

# %%
pd.merge(countries_df, countries_df2, on="Countries", how="right")
# Out:
#      Countries    Cars  Horses  Bicycles  Flowers  Electricity  \
# 0      Germany   317.0  5429.0    9273.0   8163.0       3043.0
# 1          USA  3866.0    28.0    6019.0   9709.0       9020.0
# 2        Ghana     NaN     NaN       NaN      NaN          NaN
# 3  New Zealand     NaN     NaN       NaN      NaN          NaN
#
#    Transportation  Bananas  Apples
# 0          9590.0   129295   23939
# 1          9885.0   967969  907253
# 2             NaN   913918  323985
# 3             NaN   173012  981176

# %% [markdown]
# #### Concatenation

# %%
cols = ["Bananas", "Apples"]
rows = ["Denmark", "Canada", "South Africa", "Austrialia"]
data = np.random.randint(1,1000000,(4,2))
countries_df3 = pd.DataFrame(data, columns=cols, index=rows).reset_index().rename({"index":"Countries"}, axis=1)
countries_df3
# Out:
#       Countries  Bananas  Apples
# 0       Denmark   623177  142117
# 1        Canada   333256  399512
# 2  South Africa   559043  601117
# 3    Austrialia   955841  900749

# %%
countries_df2
# Out:
#      Countries  Bananas  Apples
# 0      Germany   792738  233463
# 1          USA   855342  267340
# 2        Ghana   270960  532424
# 3  New Zealand   701745  611670

# %%
pd.concat([countries_df2, countries_df3]).reset_index(drop=True)
# Out:
#       Countries  Bananas  Apples
# 0       Germany   792738  233463
# 1           USA   855342  267340
# 2         Ghana   270960  532424
# 3   New Zealand   701745  611670
# 4       Denmark   623177  142117
# 5        Canada   333256  399512
# 6  South Africa   559043  601117
# 7    Austrialia   955841  900749

# %% [markdown]
# ### GroupBy

# %%
countries_df_large
# Out:
#      Countries    Cars  Horses  Bicycles  Flowers  Electricity  \
# 0      Germany   317.0  5429.0    9273.0   8163.0       3043.0
# 1          USA  3866.0    28.0    6019.0   9709.0       9020.0
# 2       France  6788.0  3498.0    1498.0   2156.0       1883.0
# 3        Italy   779.0  5888.0    7990.0   7024.0       5540.0
# 4        China   710.0  7861.0    7929.0   7099.0       6309.0
# 5        Ghana  2492.0  4540.8    6541.8   6830.2       5159.0
# 6  New Zealand  2492.0  4540.8    6541.8   6830.2       5159.0
#
#    Transportation    Bananas     Apples
# 0          9590.0  792738.00  233463.00
# 1          9885.0  855342.00  267340.00
# 2          8286.0  655196.25  411224.25
# 3          8769.0  655196.25  411224.25
# 4          8639.0  655196.25  411224.25
# 5          9033.8  270960.00  532424.00
# 6          9033.8  701745.00  611670.00

# %%
countries_df_large["continent"] = ["Europe", "North America", "Europe", "Europe", "Asia", "Africa", "Oceania"]

# %%
countries_df_large
# Out:
#      Countries    Cars  Horses  Bicycles  Flowers  Electricity  \
# 0      Germany   317.0  5429.0    9273.0   8163.0       3043.0
# 1          USA  3866.0    28.0    6019.0   9709.0       9020.0
# 2       France  6788.0  3498.0    1498.0   2156.0       1883.0
# 3        Italy   779.0  5888.0    7990.0   7024.0       5540.0
# 4        China   710.0  7861.0    7929.0   7099.0       6309.0
# 5        Ghana  2492.0  4540.8    6541.8   6830.2       5159.0
# 6  New Zealand  2492.0  4540.8    6541.8   6830.2       5159.0
#
#    Transportation    Bananas     Apples      continent
# 0          9590.0  792738.00  233463.00         Europe
# 1          9885.0  855342.00  267340.00  North America
# 2          8286.0  655196.25  411224.25         Europe
# 3          8769.0  655196.25  411224.25         Europe
# 4          8639.0  655196.25  411224.25           Asia
# 5          9033.8  270960.00  532424.00         Africa
# 6          9033.8  701745.00  611670.00        Oceania

# %%
countries_df_large.groupby("continent").max()
# Out:
#                  Countries    Cars  Horses  Bicycles  Flowers  Electricity  \
# continent
# Africa               Ghana  2492.0  4540.8    6541.8   6830.2       5159.0
# Asia                 China   710.0  7861.0    7929.0   7099.0       6309.0
# Europe               Italy  6788.0  5888.0    9273.0   8163.0       5540.0
# North America          USA  3866.0    28.0    6019.0   9709.0       9020.0
# Oceania        New Zealand  2492.0  4540.8    6541.8   6830.2       5159.0
#
#                Transportation    Bananas     Apples
# continent
# Africa                 9033.8  270960.00  532424.00
# Asia                   8639.0  655196.25  411224.25
# Europe                 9590.0  792738.00  411224.25
# North America          9885.0  855342.00  267340.00
# Oceania                9033.8  701745.00  611670.00

# %% [markdown]
# ## Read Data

# %%
iris_df = pd.read_csv("Data/IRIS.csv")

# %%
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_sepal_df = iris_df[["sepal_length", "sepal_width", "species"]]
iris_sepal_df
# Out:
#      sepal_length  sepal_width    species
# 0             5.1          3.5     setosa
# 1             4.9          3.0     setosa
# 2             4.7          3.2     setosa
# 3             4.6          3.1     setosa
# 4             5.0          3.6     setosa
# ..            ...          ...        ...
# 145           6.7          3.0  virginica
# 146           6.3          2.5  virginica
# 147           6.5          3.0  virginica
# 148           6.2          3.4  virginica
# 149           5.9          3.0  virginica
#
# [150 rows x 3 columns]

# %%
iris_sepal_df.to_csv("Data/SEPAL.csv")

# %%
iris_sepal_read_df = pd.read_csv("Data/SEPAL.csv", index_col=0, delimiter=",")

# %%
iris_sepal_read_df.head()
# Out:
#    sepal_length  sepal_width species
# 0           5.1          3.5  setosa
# 1           4.9          3.0  setosa
# 2           4.7          3.2  setosa
# 3           4.6          3.1  setosa
# 4           5.0          3.6  setosa
